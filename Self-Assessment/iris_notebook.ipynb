# %%
from iris import SelfAssessment as SA

# %% [markdown]
# ### Instiantiating class.

# %%
s = SA('iris.data')

# %% [markdown]
# Making plot, see `iris.png`

# %%
s.make_plot()

# %% [markdown]
# Calculating average sepal length within groups.

# %%
s.calculate_group_average('sepal_length')
# Out:
# {'Iris-setosa': 5.006,
#  'Iris-versicolor': 5.936,
#  'Iris-virginica': 6.587999999999998}

# %% [markdown]
# Calculating variance of sepal lengths within groups.

# %%
s.calculate_group_variance('sepal_length')
# Out:
# {'Iris-setosa': 0.12176400000000002,
#  'Iris-versicolor': 0.261104,
#  'Iris-virginica': 0.3962560000000001}

# %% [markdown]
# Calculating average and variance of distances from first data point to rest.

# %%
s.calculate_lengths()
# Out:
# (2.9102011451325414, 3.461199093526963)
